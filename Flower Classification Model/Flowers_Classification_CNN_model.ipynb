# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    BatchNormalization,
    LeakyReLU,
    MaxPooling2D,
    Flatten,
    Dense,
    Dropout,
)
from tensorflow.keras import layers, models


from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls "content/drive/My Drive/"
# Out:
# ls: cannot access 'content/drive/My Drive/': No such file or directory

# %%
train_dir = "/content/drive/MyDrive/flowers-20241116T133430Z-001/flowers/train/"
test_dir = "/content/drive/MyDrive/flowers-20241116T133430Z-001/flowers/test/"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set image shape and batch size
image_shape = (100, 100)
batch_size = 128

# Augmentation for training data
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # Reserve 20% of training data for validation
)

# Only rescaling for validation and test data
test_datagen = ImageDataGenerator(rescale=1./255)

# Load training data with augmentation
print("Training Images:")
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_shape,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    subset='training'
)

# Load validation data (20% of training data)
print("Validating Images:")
valid_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_shape,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False,
    subset='validation'
)

# Load test data (consider validation data as test data)
print("Test Images:")
test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_shape,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Training Images:
# Found 2514 images belonging to 5 classes.
# Validating Images:
# Found 626 images belonging to 5 classes.
# Test Images:
# Found 1228 images belonging to 5 classes.

# %%
# Extract class names from the datasets using class_indices
train_class_names = list(train_data.class_indices.keys())
valid_class_names = list(valid_data.class_indices.keys())
test_class_names = list(test_data.class_indices.keys())

# Print class names
print("Training Class Names:", train_class_names)
print("Validation Class Names:", valid_class_names)
print("Test Class Names:", test_class_names)

# Print the number of classes
print("Number of Training Classes:", len(train_class_names))
print("Number of Validation Classes:", len(valid_class_names))
print("Number of Test Classes:", len(test_class_names))
# Out:
# Training Class Names: ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
# Validation Class Names: ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
# Test Class Names: ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
# Number of Training Classes: 5
# Number of Validation Classes: 5
# Number of Test Classes: 5

# %%
class_names = train_class_names

# %%
import keras

model = keras.Sequential()

# %%
model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(100, 100, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(5, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_42 (Conv2D)                   │ (None, 98, 98, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_25 (MaxPooling2D)      │ (None, 49, 49, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_43 (Conv2D)                   │ (None, 47, 47, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_26 (MaxPooling2D)      │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_11 (Flatten)                 │ (None, 33856)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_30 (Dense)                     │ (None, 64)                  │       2,166,848 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 5)                   │             325 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,186,565 (8.34 MB)
#  Trainable params: 2,186,565 (8.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the Model
loss_fn = CategoricalCrossentropy(label_smoothing=0.1)
optimizer = Adam(learning_rate=1e-4)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

# Callbacks for training
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
callbacks = [early_stopping, reduce_lr]

# %%
# Define early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',        # Monitor validation loss
    patience=10,               # Number of epochs with no improvement after which training will stop
    restore_best_weights=True  # Restore model weights from the epoch with the best validation loss
)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model with early stopping
history = model.fit(
    train_data,
    epochs=100,
    batch_size = 128,
    validation_data=valid_data,
    callbacks= [early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.2857 - loss: 1.5736 - val_accuracy: 0.4185 - val_loss: 1.4526 - learning_rate: 1.0000e-04
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 873ms/step - accuracy: 0.4129 - loss: 1.4326 - val_accuracy: 0.4489 - val_loss: 1.3638 - learning_rate: 1.0000e-04
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.4607 - loss: 1.3549 - val_accuracy: 0.4696 - val_loss: 1.3198 - learning_rate: 1.0000e-04
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 866ms/step - accuracy: 0.4882 - loss: 1.3073 - val_accuracy: 0.4968 - val_loss: 1.2953 - learning_rate: 1.0000e-04
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 867ms/step - accuracy: 0.4913 - loss: 1.2889 - val_accuracy: 0.4696 - val_loss: 1.3169 - learning_rate: 1.0000e-04
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 853ms/step - accuracy: 0.4888 - loss: 1.2879 - val_accuracy: 0.4968 - val_loss: 1.2930 - learning_rate: 1.0000e-04
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 856ms/step - accuracy: 0.5017 - loss: 1.2760 - val_accuracy: 0.4968 - val_loss: 1.2749 - learning_rate: 1.0000e-04
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 849ms/step - accuracy: 0.5518 - loss: 1.2260 - val_accuracy: 0.5160 - val_loss: 1.2707 - learning_rate: 1.0000e-04
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 851ms/step - accuracy: 0.5308 - loss: 1.2357 - val_accuracy: 0.5256 - val_loss: 1.2692 - learning_rate: 1.0000e-04
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 844ms/step - accuracy: 0.5438 - loss: 1.2257 - val_accuracy: 0.5128 - val_loss: 1.2682 - learning_rate: 1.0000e-04
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 863ms/step - accuracy: 0.5707 - loss: 1.2050 - val_accuracy: 0.5304 - val_loss: 1.2510 - learning_rate: 1.0000e-04
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 857ms/step - accuracy: 0.5496 - loss: 1.2208 - val_accuracy: 0.5431 - val_loss: 1.2412 - learning_rate: 1.0000e-04
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 811ms/step - accuracy: 0.5671 - loss: 1.2053 - val_accuracy: 0.5607 - val_loss: 1.2427 - learning_rate: 1.0000e-04
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 847ms/step - accuracy: 0.5761 - loss: 1.1932 - val_accuracy: 0.5543 - val_loss: 1.2354 - learning_rate: 1.0000e-04
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 810ms/step - accuracy: 0.5788 - loss: 1.1916 - val_accuracy: 0.5623 - val_loss: 1.2197 - learning_rate: 1.0000e-04
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 841ms/step - accuracy: 0.5998 - loss: 1.1668 - val_accuracy: 0.5639 - val_loss: 1.2260 - learning_rate: 1.0000e-04
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 825ms/step - accuracy: 0.6109 - loss: 1.1518 - val_accuracy: 0.5527 - val_loss: 1.2163 - learning_rate: 1.0000e-04
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 804ms/step - accuracy: 0.5959 - loss: 1.1530 - val_accuracy: 0.5575 - val_loss: 1.2310 - learning_rate: 1.0000e-04
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 874ms/step - accuracy: 0.5895 - loss: 1.1431 - val_accuracy: 0.6166 - val_loss: 1.1959 - learning_rate: 1.0000e-04
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 860ms/step - accuracy: 0.6021 - loss: 1.1552 - val_accuracy: 0.6022 - val_loss: 1.1905 - learning_rate: 1.0000e-04
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 831ms/step - accuracy: 0.6053 - loss: 1.1477 - val_accuracy: 0.5783 - val_loss: 1.2103 - learning_rate: 1.0000e-04
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 827ms/step - accuracy: 0.6032 - loss: 1.1429 - val_accuracy: 0.6022 - val_loss: 1.1786 - learning_rate: 1.0000e-04
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 831ms/step - accuracy: 0.6113 - loss: 1.1378 - val_accuracy: 0.5895 - val_loss: 1.1805 - learning_rate: 1.0000e-04
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 882ms/step - accuracy: 0.6090 - loss: 1.1276 - val_accuracy: 0.5847 - val_loss: 1.1920 - learning_rate: 1.0000e-04
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 859ms/step - accuracy: 0.6092 - loss: 1.1248 - val_accuracy: 0.5958 - val_loss: 1.1619 - learning_rate: 1.0000e-04
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 821ms/step - accuracy: 0.6423 - loss: 1.1003 - val_accuracy: 0.5927 - val_loss: 1.1690 - learning_rate: 1.0000e-04
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 870ms/step - accuracy: 0.6223 - loss: 1.1110 - val_accuracy: 0.5687 - val_loss: 1.1731 - learning_rate: 1.0000e-04
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 820ms/step - accuracy: 0.6276 - loss: 1.1092 - val_accuracy: 0.6166 - val_loss: 1.1512 - learning_rate: 1.0000e-04
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 835ms/step - accuracy: 0.6433 - loss: 1.0889 - val_accuracy: 0.6134 - val_loss: 1.1724 - learning_rate: 1.0000e-04
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 870ms/step - accuracy: 0.6230 - loss: 1.1013 - val_accuracy: 0.5895 - val_loss: 1.1585 - learning_rate: 1.0000e-04
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 868ms/step - accuracy: 0.6356 - loss: 1.0978 - val_accuracy: 0.6150 - val_loss: 1.1370 - learning_rate: 1.0000e-04
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 845ms/step - accuracy: 0.6686 - loss: 1.0694 - val_accuracy: 0.5767 - val_loss: 1.1748 - learning_rate: 1.0000e-04
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 850ms/step - accuracy: 0.6438 - loss: 1.0855 - val_accuracy: 0.6070 - val_loss: 1.1352 - learning_rate: 1.0000e-04
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 859ms/step - accuracy: 0.6448 - loss: 1.0824 - val_accuracy: 0.6118 - val_loss: 1.1530 - learning_rate: 1.0000e-04
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 820ms/step - accuracy: 0.6366 - loss: 1.0928 - val_accuracy: 0.5895 - val_loss: 1.1528 - learning_rate: 1.0000e-04
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 873ms/step - accuracy: 0.6344 - loss: 1.0830 - val_accuracy: 0.6054 - val_loss: 1.1287 - learning_rate: 1.0000e-04
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 849ms/step - accuracy: 0.6444 - loss: 1.0625 - val_accuracy: 0.6054 - val_loss: 1.1409 - learning_rate: 1.0000e-04
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 845ms/step - accuracy: 0.6514 - loss: 1.0605 - val_accuracy: 0.6070 - val_loss: 1.1277 - learning_rate: 1.0000e-04
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 807ms/step - accuracy: 0.6449 - loss: 1.0710 - val_accuracy: 0.5927 - val_loss: 1.1385 - learning_rate: 1.0000e-04
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 825ms/step - accuracy: 0.6580 - loss: 1.0461 - val_accuracy: 0.6182 - val_loss: 1.1227 - learning_rate: 1.0000e-04
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 823ms/step - accuracy: 0.6598 - loss: 1.0671 - val_accuracy: 0.6214 - val_loss: 1.1260 - learning_rate: 1.0000e-04
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.6618 - loss: 1.0669 - val_accuracy: 0.6470 - val_loss: 1.1030 - learning_rate: 1.0000e-04
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 832ms/step - accuracy: 0.6389 - loss: 1.0680 - val_accuracy: 0.6134 - val_loss: 1.0985 - learning_rate: 1.0000e-04
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 824ms/step - accuracy: 0.6548 - loss: 1.0653 - val_accuracy: 0.6422 - val_loss: 1.0994 - learning_rate: 1.0000e-04
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 832ms/step - accuracy: 0.6604 - loss: 1.0525 - val_accuracy: 0.6230 - val_loss: 1.1318 - learning_rate: 1.0000e-04
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 870ms/step - accuracy: 0.6722 - loss: 1.0454 - val_accuracy: 0.6070 - val_loss: 1.1175 - learning_rate: 1.0000e-04
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 830ms/step - accuracy: 0.6752 - loss: 1.0349 - val_accuracy: 0.6246 - val_loss: 1.1158 - learning_rate: 1.0000e-04
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 847ms/step - accuracy: 0.6476 - loss: 1.0590 - val_accuracy: 0.6054 - val_loss: 1.1287 - learning_rate: 1.0000e-04
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 857ms/step - accuracy: 0.6646 - loss: 1.0576 - val_accuracy: 0.6406 - val_loss: 1.0885 - learning_rate: 5.0000e-05
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 860ms/step - accuracy: 0.6744 - loss: 1.0290 - val_accuracy: 0.6406 - val_loss: 1.1029 - learning_rate: 5.0000e-05
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 808ms/step - accuracy: 0.6631 - loss: 1.0361 - val_accuracy: 0.6470 - val_loss: 1.1046 - learning_rate: 5.0000e-05
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 825ms/step - accuracy: 0.6833 - loss: 1.0229 - val_accuracy: 0.6390 - val_loss: 1.0803 - learning_rate: 5.0000e-05
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 835ms/step - accuracy: 0.6816 - loss: 1.0145 - val_accuracy: 0.6150 - val_loss: 1.1061 - learning_rate: 5.0000e-05
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 889ms/step - accuracy: 0.6646 - loss: 1.0136 - val_accuracy: 0.6342 - val_loss: 1.0854 - learning_rate: 5.0000e-05
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 852ms/step - accuracy: 0.6839 - loss: 1.0141 - val_accuracy: 0.6406 - val_loss: 1.0768 - learning_rate: 5.0000e-05
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 840ms/step - accuracy: 0.6928 - loss: 1.0066 - val_accuracy: 0.6550 - val_loss: 1.0881 - learning_rate: 5.0000e-05
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 794ms/step - accuracy: 0.6784 - loss: 1.0160 - val_accuracy: 0.6422 - val_loss: 1.0920 - learning_rate: 5.0000e-05
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 840ms/step - accuracy: 0.6593 - loss: 1.0388 - val_accuracy: 0.6438 - val_loss: 1.0862 - learning_rate: 5.0000e-05
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 845ms/step - accuracy: 0.6932 - loss: 1.0056 - val_accuracy: 0.6374 - val_loss: 1.0936 - learning_rate: 5.0000e-05
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 827ms/step - accuracy: 0.6820 - loss: 1.0093 - val_accuracy: 0.6278 - val_loss: 1.0943 - learning_rate: 5.0000e-05
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 838ms/step - accuracy: 0.6725 - loss: 1.0245 - val_accuracy: 0.6358 - val_loss: 1.0838 - learning_rate: 2.5000e-05
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 817ms/step - accuracy: 0.6916 - loss: 0.9998 - val_accuracy: 0.6326 - val_loss: 1.0996 - learning_rate: 2.5000e-05
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 835ms/step - accuracy: 0.6920 - loss: 1.0077 - val_accuracy: 0.6486 - val_loss: 1.0805 - learning_rate: 2.5000e-05
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 895ms/step - accuracy: 0.6779 - loss: 1.0159 - val_accuracy: 0.6406 - val_loss: 1.0999 - learning_rate: 2.5000e-05
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 854ms/step - accuracy: 0.6825 - loss: 1.0218 - val_accuracy: 0.6454 - val_loss: 1.0923 - learning_rate: 2.5000e-05

# %% [markdown]
# # Testing and Evaluation

# %%
Y_pred = model.predict(test_data)
score = model.evaluate(test_data)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 559ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 664ms/step - accuracy: 0.6659 - loss: 1.0823
# Test loss: 1.0279757976531982
# Test accuracy: 0.6775244474411011

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
import numpy as np

# Define class names (replace these with actual class names if available)
CLASS_NAMES = class_names

# Function to plot accuracy and loss curves
def plot_training_curves(history):
    plt.figure(figsize=(12, 4))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.show()

# Call the function to plot curves
plot_training_curves(history)

# %%
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns

# Predict on validation data
Y_pred = model.predict(valid_data)
Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_true = valid_data.classes  # Actual class labels from validation data

# Generate a classification report
CLASS_NAMES = list(valid_data.class_indices.keys())  # Extract class names from validation data generator
print("Classification Report:\n", classification_report(Y_true, Y_pred_classes, target_names=class_names))

# Calculate precision, recall, and F1-score
precision = precision_score(Y_true, Y_pred_classes, average='weighted')
recall = recall_score(Y_true, Y_pred_classes, average='weighted')
f1 = f1_score(Y_true, Y_pred_classes, average='weighted')
print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')

# Calculate normalized confusion matrix
conf_matrix = confusion_matrix(Y_true, Y_pred_classes, normalize='true')

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', xticklabels=class_names, yticklabels=class_names, fmt='.2f')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 898ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#        daisy       0.68      0.64      0.66       108
#    dandelion       0.67      0.71      0.69       164
#         rose       0.42      0.49      0.45       108
#    sunflower       0.75      0.65      0.70        98
#        tulip       0.61      0.58      0.60       148
#
#     accuracy                           0.62       626
#    macro avg       0.63      0.62      0.62       626
# weighted avg       0.63      0.62      0.62       626
#
# Precision: 0.6292, Recall: 0.6214, F1 Score: 0.6240
